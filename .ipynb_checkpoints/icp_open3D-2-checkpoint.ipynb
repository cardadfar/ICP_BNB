# %%
import numpy as np
import cvxpy as cp
import heapdict
from sklearn.neighbors import NearestNeighbors
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d, Axes3D
import time

from pytransform3d.rotations import *

import open3d as o3d
import copy

# %%
def pc_to_np(open3d_data):
    return np.asarray(open3d_data.points)

def np_to_pc(np_data):
    pcd = o3d.geometry.PointCloud()
    pcd.points = o3d.utility.Vector3dVector(np_data)
    return pcd

def np_to_tuple(data):
    return tuple(data.flatten())

def tuple_to_np(data):
    return (np.asarray(list(data))).reshape((4,4))

def rotation_matrix(euler):
    R = np.identity(4)
    R[0:3,0:3] = matrix_from_euler_xyz(euler)
    return R

def scale_matrix(euler):
    S = np.identity(4)
    S[0,0] = euler[0]
    S[1,1] = euler[1]
    S[2,2] = euler[2]
    return S

def translation_matrix(euler):
    T = np.identity(4)
    T[0,3] = euler[0]
    T[1,3] = euler[1]
    T[2,3] = euler[2]
    return T

# %%
def draw_registration_result(source, target, transformation):
    source_temp = copy.deepcopy(source)
    target_temp = copy.deepcopy(target)
    source_temp.paint_uniform_color([1, 0.706, 0])
    target_temp.paint_uniform_color([0, 0.651, 0.929])
    source_temp.transform(transformation)
    o3d.visualization.draw_geometries([source_temp, target_temp])

def icp(source, target, T_init, threshold=0.8):
    
    evaluation = o3d.registration.evaluate_registration(source, target, threshold, T_init)

    reg_p2p = o3d.registration.registration_icp(source, target, threshold, T_init, 
                                                o3d.registration.TransformationEstimationPointToPoint())
    
    return reg_p2p.transformation

# %%
def compute_dist(src,tgt,T):
    src_cpy = copy.deepcopy(src)
    src_t = src_cpy.transform(T)
    
    src_np = pc_to_np(src_t)
    tgt_np = pc_to_np(tgt)
    
    neigh = NearestNeighbors(n_neighbors=1)
    neigh.fit(tgt_np)
    distances, indices = neigh.kneighbors(src_np, return_distance=True)
    distances = distances.ravel()
    indices = indices.ravel()
    
    numUnique = len(np.unique(indices))
    
    eps = 0.1
    sumAboveEps = np.sum(np.where(distances > eps, distances, 0))
    
    return distances, numUnique, sumAboveEps

# %%
src_ref = "data/model_bunny.txt"
tgt_ref = "data/generated_bunny.txt"

source = o3d.io.read_point_cloud(src_ref, format='xyz')
target = o3d.io.read_point_cloud(tgt_ref, format='xyz')


# APPLY RANDOM TRANSFORMATION TO TARGET


p2p = np.identity(4)

R = rotation_matrix(10*np.random.rand(3))
p2p = np.dot(R,p2p)

'''
ratio = 1.3
S = scale_matrix([ratio,ratio,ratio])
p2p = np.dot(S,p2p)

T = translation_matrix([0.1,0.2,-0.1])
p2p = np.dot(T,p2p)
'''

target.transform(p2p)




T_iden = np.identity(4)
draw_registration_result(source,target,T_iden)

# %%
T_iden = np.identity(4)

distances, numUnique, sumAboveEps = compute_dist(source,target,T_iden)
print("Net distance: %.3f | Sum above eps: %.3f | Unique matchings: %d" % (np.sum(distances), sumAboveEps, numUnique ))


p2p = np.identity(4)


maxIters = 80
i = 0
prevSumAboveEps = 0

hd = heapdict.heapdict()
hd_size = 0



d = 3
pi = 3.14
for i in range(-d,d):
    for j in range(-d,d):
        for k in range(-d,d):
            R = rotation_matrix([2*pi*(i/d),2*pi*(j/d),2*pi*(k/d)])

            distances, numUnique, sumAboveEps = compute_dist(source, target, np.dot(R,p2p))
            hd[np_to_tuple(np.dot(R,p2p))] = sumAboveEps
            hd_size += 1



while(i < maxIters) and (hd_size > 0):
    
    p2p, prevSumAboveEps = hd.popitem()
    p2p = tuple_to_np(p2p)
    hd_size -= 1
    
    p2p = icp(source, target, p2p, threshold=0.8)
    distances, numUnique, sumAboveEps = compute_dist(source, target, p2p)
    
    print("%d Net distance: %.3f | Sum above eps: %.3f | Unique matchings: %d" % i, (np.sum(distances), sumAboveEps, numUnique ))

    if(sumAboveEps < 0.005):
        break
    
    '''
    if(abs(sumAboveEps - prevSumAboveEps) < 5.0):
        
        print('adding new rotations...')
        d = 2
        pi = 3.14
        for i in range(-d,d):
            for j in range(-d,d):
                for k in range(-d,d):
                    if not ( i == 0 and j == 0 and k == 0):
                        R = rotation_matrix([2*pi*(i/d),2*pi*(j/d),2*pi*(k/d)])

                        distances, numUnique, sumAboveEps = compute_dist(source, target, np.dot(R,p2p))
                        hd[np_to_tuple(np.dot(R,p2p))] = sumAboveEps
                        hd_size += 1
        
        print('done adding.')
    '''
        
    if(abs(sumAboveEps - prevSumAboveEps) > 5.0):
        hd[np_to_tuple(p2p)] = sumAboveEps
        hd_size += 1
    
    i += 1

print()
print(p2p)
# Out:
# Net distance: 4992.852 | Sum above eps: 4291.834 | Unique matchings: 2899
# Net distance: 1709.018 | Sum above eps: 618.355 | Unique matchings: 5718
# Net distance: 1651.436 | Sum above eps: 515.065 | Unique matchings: 5836
# Net distance: 1637.697 | Sum above eps: 503.246 | Unique matchings: 5803
# Net distance: 1637.302 | Sum above eps: 503.908 | Unique matchings: 5804
# Net distance: 1707.829 | Sum above eps: 617.593 | Unique matchings: 5724
# Net distance: 1651.257 | Sum above eps: 514.851 | Unique matchings: 5838
# Net distance: 1637.683 | Sum above eps: 503.262 | Unique matchings: 5812
# Net distance: 1637.311 | Sum above eps: 503.908 | Unique matchings: 5807
# Net distance: 1709.166 | Sum above eps: 618.650 | Unique matchings: 5720
# Net distance: 1651.700 | Sum above eps: 515.592 | Unique matchings: 5837
# Net distance: 1637.696 | Sum above eps: 502.798 | Unique matchings: 5795
# Net distance: 1637.263 | Sum above eps: 504.056 | Unique matchings: 5801
# Net distance: 1707.983 | Sum above eps: 616.491 | Unique matchings: 5728
# Net distance: 1651.414 | Sum above eps: 515.012 | Unique matchings: 5841
# Net distance: 1637.618 | Sum above eps: 502.942 | Unique matchings: 5814
# Net distance: 1637.207 | Sum above eps: 504.204 | Unique matchings: 5807
# Net distance: 1709.504 | Sum above eps: 618.868 | Unique matchings: 5710
# Net distance: 1651.599 | Sum above eps: 515.593 | Unique matchings: 5845
# Net distance: 1637.745 | Sum above eps: 503.125 | Unique matchings: 5799
# Net distance: 1637.317 | Sum above eps: 503.798 | Unique matchings: 5809
# Net distance: 1708.244 | Sum above eps: 617.473 | Unique matchings: 5723
# Net distance: 1651.394 | Sum above eps: 515.464 | Unique matchings: 5836
# Net distance: 1637.682 | Sum above eps: 503.181 | Unique matchings: 5791
# Net distance: 1637.263 | Sum above eps: 504.143 | Unique matchings: 5789
# Net distance: 1709.589 | Sum above eps: 620.019 | Unique matchings: 5725
# Net distance: 1651.830 | Sum above eps: 515.637 | Unique matchings: 5829
# Net distance: 1637.705 | Sum above eps: 502.587 | Unique matchings: 5797
# Net distance: 1637.246 | Sum above eps: 503.763 | Unique matchings: 5798
# Net distance: 1708.239 | Sum above eps: 616.687 | Unique matchings: 5733
# Net distance: 1651.475 | Sum above eps: 515.264 | Unique matchings: 5844
# Net distance: 1637.637 | Sum above eps: 503.022 | Unique matchings: 5804
# Net distance: 1637.249 | Sum above eps: 504.173 | Unique matchings: 5804
# Net distance: 1882.402 | Sum above eps: 795.465 | Unique matchings: 5011
# Net distance: 1699.473 | Sum above eps: 573.844 | Unique matchings: 5499
# Net distance: 1663.100 | Sum above eps: 537.099 | Unique matchings: 5675
# Net distance: 1645.125 | Sum above eps: 531.867 | Unique matchings: 5783
# Net distance: 1638.427 | Sum above eps: 518.527 | Unique matchings: 5812
# Net distance: 1638.714 | Sum above eps: 508.685 | Unique matchings: 5818
# Net distance: 1638.972 | Sum above eps: 503.532 | Unique matchings: 5807
# Net distance: 1639.065 | Sum above eps: 503.652 | Unique matchings: 5798
# Net distance: 1880.792 | Sum above eps: 794.507 | Unique matchings: 5033
# Net distance: 1698.475 | Sum above eps: 573.018 | Unique matchings: 5516
# Net distance: 1662.711 | Sum above eps: 536.038 | Unique matchings: 5674
# Net distance: 1644.971 | Sum above eps: 532.176 | Unique matchings: 5782
# Net distance: 1883.714 | Sum above eps: 796.212 | Unique matchings: 5014
# Net distance: 1699.942 | Sum above eps: 573.670 | Unique matchings: 5496
# Net distance: 1663.376 | Sum above eps: 537.773 | Unique matchings: 5683
# Net distance: 1645.267 | Sum above eps: 531.891 | Unique matchings: 5799
# Net distance: 1638.441 | Sum above eps: 518.241 | Unique matchings: 5817
# Net distance: 1638.711 | Sum above eps: 508.680 | Unique matchings: 5817
# Net distance: 1639.068 | Sum above eps: 503.449 | Unique matchings: 5802
# Net distance: 1639.115 | Sum above eps: 503.512 | Unique matchings: 5805
# Net distance: 1882.214 | Sum above eps: 795.363 | Unique matchings: 5026
# Net distance: 1698.993 | Sum above eps: 572.771 | Unique matchings: 5498
# Net distance: 1662.878 | Sum above eps: 536.408 | Unique matchings: 5681
# Net distance: 1645.056 | Sum above eps: 532.083 | Unique matchings: 5793
# Net distance: 1882.576 | Sum above eps: 795.963 | Unique matchings: 5018
# Net distance: 1698.835 | Sum above eps: 573.680 | Unique matchings: 5502
# Net distance: 1663.054 | Sum above eps: 536.968 | Unique matchings: 5679
# Net distance: 1645.036 | Sum above eps: 532.116 | Unique matchings: 5782
# Net distance: 1881.290 | Sum above eps: 793.998 | Unique matchings: 5039
# Net distance: 1698.206 | Sum above eps: 572.609 | Unique matchings: 5510
# Net distance: 1662.497 | Sum above eps: 536.094 | Unique matchings: 5670
# Net distance: 1644.793 | Sum above eps: 532.068 | Unique matchings: 5782
# Net distance: 1883.465 | Sum above eps: 796.679 | Unique matchings: 5011
# Net distance: 1699.278 | Sum above eps: 573.746 | Unique matchings: 5493
# Net distance: 1663.082 | Sum above eps: 536.935 | Unique matchings: 5680
# Net distance: 1645.119 | Sum above eps: 532.258 | Unique matchings: 5788
# Net distance: 1882.029 | Sum above eps: 796.095 | Unique matchings: 5036
# Net distance: 1698.330 | Sum above eps: 573.400 | Unique matchings: 5502
# Net distance: 1662.760 | Sum above eps: 536.459 | Unique matchings: 5672
# Net distance: 1644.892 | Sum above eps: 531.945 | Unique matchings: 5784
# Net distance: 1608.697 | Sum above eps: 646.663 | Unique matchings: 6173
# Net distance: 1419.939 | Sum above eps: 425.030 | Unique matchings: 6397
# Net distance: 1315.704 | Sum above eps: 326.799 | Unique matchings: 6656
# Net distance: 1177.574 | Sum above eps: 185.732 | Unique matchings: 6998
# Net distance: 1018.969 | Sum above eps: 62.504 | Unique matchings: 7466
# Net distance: 849.889 | Sum above eps: 4.319 | Unique matchings: 8541
#
# [[ 0.87038834 -0.48748075  0.06918567  0.00841214]
#  [-0.46124318 -0.7581149   0.46099515 -0.00746326]
#  [-0.17227558 -0.43315622 -0.88470154 -0.07172491]
#  [ 0.          0.          0.          1.        ]]

# %%
R = rotation_matrix([0,0,0])


draw_registration_result(source,target, np.dot(R, p2p))
